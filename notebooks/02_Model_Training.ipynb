# %% [markdown]
# # 02 - Model Training
# This notebook trains various models and saves them.

# %%
import sys
sys.path.append('../')
from src.data_preprocessing import load_heart_disease_data
from src.model_training import train_all_models
from src.evaluation import evaluate_all_models

# %%
X_heart, y_heart, le_heart, scaler_heart = load_heart_disease_data('../Datasets/UCI Heart Disease (Cleveland) Dataset/heart_disease_uci.csv')

# %%
models = train_all_models(X_heart, y_heart, 'Heart Disease')
print('Models Trained Successfully!')

# %%
results = evaluate_all_models(models, X_heart, y_heart)
display(results)
